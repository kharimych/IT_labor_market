# %%
import requests
import numpy as np
import pandas as pd
import time
from bs4 import BeautifulSoup
from fake_useragent import UserAgent

# %%
page_link = 'https://hh.ru/search/resume?logic=normal&pos=full_text&exp_period=all_time&filter_exp_period=all_time&relocation=living_or_relocation&gender=unknown&order_by=relevance&search_period=0&items_on_page=100&no_magic=true&hhtmFrom=resume_search_form&area=113&label=only_with_salary&professional_role=96&text=%D1%80%D0%B0%D0%B7%D1%80%D0%B0%D0%B1%D0%BE%D1%82%D1%87%D0%B8%D0%BA'
UserAgent().chrome
response = requests.get(page_link, headers={'User-Agent': UserAgent().chrome})

response
# Out:
# <Response [200]>

# %%
html = response.content
soup = BeautifulSoup(html,'html.parser')

# %% [markdown]
# В первой строчке получаем столбцы(характеристики) для нашего датафрейма. Все они лежат в теге div с классом resume-block. Далее для каждой характеристики кандидата получаем текст, который он написал в эту категорию, и добавляем его в список

# %%
def get_information_about_candidate1(soup):
    obj = soup.findAll('div', attrs = {'data-qa':'resume-serp__resume'})
    employers_data_frame = pd.DataFrame(columns = ['опыт работы', 'регион', 'пол', 'возраст', 'образование', 'вуз', 'язык', 'занятость', 'желаемая з/п', 'Последнее место работы'])
    for resume in obj:
        employer_id = resume.a.attrs['href']
        employer_id = 'https://hh.ru' + employer_id
        employer_response = requests.get(employer_id, headers={'User-Agent': UserAgent().chrome})
        employer_html = employer_response.content
        employer_soup = BeautifulSoup(employer_html,'html.parser')
        employers_data_frame.loc[len(employers_data_frame)] = None
        try:
            employers_data_frame.iat[-1, 3] = employer_soup.find('span', attrs = {'data-qa' : "resume-personal-age"}).text
        except:
            employers_data_frame.iat[-1, 3] = employer_soup.find('span', attrs = {'data-qa' : "resume-personal-age"})
        try:
            employers_data_frame.iat[-1, 2] = employer_soup.find('span', attrs = {'data-qa' : "resume-personal-gender"}).text
        except:
            employers_data_frame.iat[-1, 2] = employer_soup.find('span', attrs = {'data-qa' : "resume-personal-gender"})
        try:
            ebanutsa = employer_soup.findAll('div', attrs = {'class' : 'resume-block-container'})
            for i in range(len(ebanutsa)):
                if ebanutsa[i].p == None:
                    pass
                else:
                    employers_data_frame.iat[-1, 7] = ebanutsa[i].p.text
                    break
        except:
            pass
        try:
            employers_data_frame.iat[-1, 8] = employer_soup.find('span', attrs = {'class' : 'resume-block__salary'}).text
        except:
            employers_data_frame.iat[-1, 8] = employer_soup.find('span', attrs = {'class' : 'resume-block__salary'})
        try:
            employers_data_frame.iat[-1, 0] = employer_soup.find('span', attrs = {'class' : 'resume-block__title-text resume-block__title-text_sub'}).span.text
        except:
            pass
        try:
            employers_data_frame.iat[-1, 1] = employer_soup.find('span', attrs = {'data-qa' : 'resume-personal-address'}).text
        except:
            employers_data_frame.iat[-1, 1] = employer_soup.find('span', attrs = {'data-qa' : 'resume-personal-address'})
        try:
            employers_data_frame.iat[-1, 4] = employer_soup.find('div', attrs = {'data-qa' : 'resume-block-education'}).span.text
        except:
            pass
        try:
            employers_data_frame.iat[-1, 5] = employer_soup.find('div', attrs = {'data-qa' : 'resume-block-education-name'}).text
        except:
            pass
        try:
            employers_data_frame.iat[-1, 9] = employer_soup.find('div', attrs = {'class' : "bloko-column bloko-column_xs-4 bloko-column_s-2 bloko-column_m-2 bloko-column_l-2"}).text
        except:
            pass
        try:
            ebanutsax2 = employer_soup.findAll('p', attrs = {'data-qa' : 'resume-block-language-item'})
            employers_data_frame.iat[-1, 6] = ' '.join([i.text for i in ebanutsax2])
        except:
            pass

    return employers_data_frame

# %%
get_information_about_candidate1(soup)
# Out:
#    опыт работы       регион      пол   возраст  \
# 0       17 лет       Москва  Мужчина    39 лет
# 1       18 лет       Москва  Мужчина    37 лет
# 2       3 года       Москва  Мужчина   32 года
# 3     25 years        Tomsk     Male  56 years
# 4       3 года       Москва  Мужчина    27 лет
# 5       2 года       Москва  Мужчина    27 лет
# 6       3 года       Москва  Мужчина   32 года
# 7       15 лет       Москва  Мужчина   54 года
# 8       17 лет       Москва  Мужчина    37 лет
# 9        5 лет       Москва  Мужчина   22 года
# 10       1 год       Москва  Мужчина      None
# 11      4 года       Москва  Мужчина    25 лет
# 12      15 лет       Москва  Мужчина    66 лет
# 13      20 лет       Москва  Мужчина    39 лет
# 14       7 лет  Новосибирск  Мужчина   34 года
# 15      4 года       Москва  Мужчина   24 года
# 16       1 год      Саратов  Мужчина   33 года
# 17      19 лет       Москва  Мужчина    40 лет
# 18       1 год       Москва  Мужчина   32 года
# 19      3 года       Москва  Мужчина    25 лет
#
#                         образование  \
# 0                Высшее образование
# 1                       Образование
# 2                Высшее образование
# 3                  Higher education
# 4                Высшее образование
# 5      Высшее образование (Магистр)
# 6     Высшее образование (Бакалавр)
# 7                       Образование
# 8                       Образование
# 9                Высшее образование
# 10     Высшее образование (Магистр)
# 11  Среднее специальное образование
# 12               Высшее образование
# 13  Неоконченное высшее образование
# 14               Высшее образование
# 15  Неоконченное высшее образование
# 16               Высшее образование
# 17               Высшее образование
# 18               Высшее образование
# 19  Неоконченное высшее образование
#
#                                                   вуз  \
# 0                 Томский политехнический университет
# 1                                                 NaN
# 2   Московский государственный технический универс...
# 3   Томский Институт Автоматизированных Систем Упр...
# 4                                                ГГТУ
# 5   Российский государственный университет нефти и...
# 6   Российский государственный социальный универси...
# 7                                                 NaN
# 8                                                 NaN
# 9      Московский политехнический университет, Москва
# 10  Национальный исследовательский университет "Вы...
# 11               Российский новый университет, Москва
# 12                 Московский Энергетический Институт
# 13  Московский государственный технический универс...
# 14       Братский государственный университет, Братск
# 15  Московский авиационный институт (национальный ...
# 16  Донецкий национальный технический университет,...
# 17                                   МГТУ им. Баумана
# 18  Московский государственный строительный универ...
# 19      Международный инновационный университет, Сочи
#
#                                                  язык  \
# 0   Английский — C2 — В совершенстве Русский — B2 ...
# 1                                    Русский — Родной
# 2          Русский — Родной Английский — B1 — Средний
# 3        Russian — Native English — B1 — Intermediate
# 4   Русский — Родной Английский — B2 — Средне-прод...
# 5          Русский — Родной Английский — B1 — Средний
# 6          Русский — Родной Английский — B1 — Средний
# 7                Английский — B2 — Средне-продвинутый
# 8                    Английский — C2 — В совершенстве
# 9   Русский — Родной Английский — B2 — Средне-прод...
# 10  Русский — Родной Английский — C2 — В совершенс...
# 11         Русский — Родной Английский — B1 — Средний
# 12               Английский — B2 — Средне-продвинутый
# 13  Русский — Родной Английский — B2 — Средне-прод...
# 14       Русский — Родной Английский — A1 — Начальный
# 15  Русский — Родной Английский — B2 — Средне-прод...
# 16         Русский — Родной Английский — B1 — Средний
# 17  Русский — Родной Английский — B2 — Средне-прод...
# 18         Русский — Родной Английский — B1 — Средний
# 19    Русский — Родной Английский — A2 — Элементарный
#
#                                            занятость       желаемая з/п  \
# 0                        Занятость: полная занятость                NaN
# 1                        Занятость: полная занятость                NaN
# 2                        Занятость: полная занятость                NaN
# 3     Employment: full time, part time, project work   50 000 ₽ in hand
# 4                        Занятость: полная занятость               None
# 5                        Занятость: полная занятость               None
# 6   Занятость: полная занятость, частичная занятость               None
# 7                        Занятость: полная занятость               None
# 8                        Занятость: полная занятость   70 000 ₽ на руки
# 9                        Занятость: полная занятость               None
# 10                       Занятость: полная занятость               None
# 11                       Занятость: полная занятость               None
# 12                       Занятость: полная занятость    2 700 $ на руки
# 13                       Занятость: полная занятость   60 000 ₽ на руки
# 14                       Занятость: полная занятость  140 000 ₽ на руки
# 15  Занятость: полная занятость, частичная занятость  180 000 ₽ на руки
# 16                       Занятость: полная занятость               None
# 17                       Занятость: полная занятость  150 000 ₽ на руки
# 18                       Занятость: полная занятость               None
# 19           Занятость: полная занятость, стажировка               None
#
#                                Последнее место работы
# 0     Апрель 2008 — по настоящее время16 лет 2 месяца
# 1   Октябрь 2005 — по настоящее время18 лет 8 месяцев
# 2         Май 2021 — по настоящее время3 года 1 месяц
# 3         September 1998 — currently25 years 9 months
# 4      Апрель 2023 — по настоящее время1 год 2 месяца
# 5   Октябрь 2021 — по настоящее время2 года 8 месяцев
# 6             Ноябрь 2020 — Ноябрь 20233 года 1 месяц
# 7   Сентябрь 2008 — по настоящее время15 лет 9 мес...
# 8         Май 2007 — по настоящее время17 лет 1 месяц
# 9     Февраль 2023 — по настоящее время1 год 4 месяца
# 10        Сентябрь 2023 — по настоящее время9 месяцев
# 11  Сентябрь 2019 — по настоящее время4 года 9 мес...
# 12   Февраль 2009 — по настоящее время15 лет 4 месяца
# 13   Декабрь 2014 — по настоящее время9 лет 6 месяцев
# 14          Декабрь 2021 — Декабрь 20232 года 1 месяц
# 15          Ноябрь 2023 — по настоящее время7 месяцев
# 16       Март 2023 — по настоящее время1 год 3 месяца
# 17     Апрель 2017 — по настоящее время7 лет 2 месяца
# 18    Февраль 2023 — по настоящее время1 год 4 месяца
# 19  Декабрь 2020 — по настоящее время3 года 6 месяцев

# %%
employers_data_frame = pd.DataFrame(columns = ['опыт работы', 'регион', 'пол', 'возраст', 'образование', 'вуз', 'язык', 'занятость', 'желаемая з/п', 'Последнее место работы'])
for i in range(50):
    page_link = 'https://hh.ru/search/resume?logic=normal&pos=full_text&exp_period=all_time&filter_exp_period=all_time&relocation=living_or_relocation&gender=unknown&order_by=relevance&search_period=0&items_on_page=100&no_magic=true&hhtmFrom=resume_search_form&area=113&label=only_with_salary&professional_role=96&text=%D1%80%D0%B0%D0%B7%D1%80%D0%B0%D0%B1%D0%BE%D1%82%D1%87%D0%B8%D0%BA'+'&page={}'.format(i)
    UserAgent().chrome
    response = requests.get(page_link, headers={'User-Agent': UserAgent().chrome})
    html = response.content
    soup = BeautifulSoup(html,'html.parser')
    employers_data_frame = pd.concat([employers_data_frame, get_information_about_candidate1(soup)], ignore_index = True)

# %%
employers_data_frame
# Out:
#     опыт работы           регион      пол   возраст  \
# 0       24 года  Санкт-Петербург  Мужчина    45 лет
# 1        26 лет           Самара  Мужчина    49 лет
# 2        2 года     Екатеринбург  Мужчина   23 года
# 3      25 years            Tomsk     Male  56 years
# 4        12 лет            Пермь  Мужчина    38 лет
# ..          ...              ...      ...       ...
# 395       9 лет          Барнаул  Женщина   32 года
# 396       1 год           Москва  Мужчина    29 лет
# 397      18 лет          Саратов  Мужчина   42 года
# 398       7 лет          Вологда  Мужчина    28 лет
# 399      2 года           Москва  Мужчина   24 года
#
#                             образование  \
# 0       Неоконченное высшее образование
# 1                    Высшее образование
# 2       Неоконченное высшее образование
# 3                      Higher education
# 4                    Высшее образование
# ..                                  ...
# 395                  Высшее образование
# 396     Неоконченное высшее образование
# 397  Высшее образование (Кандидат наук)
# 398        Высшее образование (Магистр)
# 399     Среднее специальное образование
#
#                                                    вуз  \
# 0                                    Академия Культуры
# 1    Самарский государственный аэрокосмический унив...
# 2    Уральский федеральный университет имени первог...
# 3    Томский Институт Автоматизированных Систем Упр...
# 4    Пермский национальный исследовательский полите...
# ..                                                 ...
# 395  Алтайский государственный технический универси...
# 396  Московский государственный технический универс...
# 397            Саратовский государственный университет
# 398  Вологодский государственный технический универ...
# 399  Московский энергетический институт (Национальн...
#
#                                                   язык  \
# 0           Русский — Родной Английский — B1 — Средний
# 1    Русский — Родной Английский — B2 — Средне-прод...
# 2           Русский — Родной Английский — B1 — Средний
# 3         Russian — Native English — B1 — Intermediate
# 4    Русский — Родной Английский — B2 — Средне-прод...
# ..                                                 ...
# 395  Русский — Родной Английский — B2 — Средне-прод...
# 396                                   Русский — Родной
# 397  Русский — Родной Английский — B2 — Средне-прод...
# 398    Русский — Родной Английский — A2 — Элементарный
# 399         Русский — Родной Английский — B1 — Средний
#
#                                              занятость       желаемая з/п  \
# 0                          Занятость: полная занятость  100 000 ₽ на руки
# 1                          Занятость: полная занятость    1 599 € на руки
# 2                          Занятость: полная занятость  200 000 ₽ на руки
# 3       Employment: full time, part time, project work   50 000 ₽ in hand
# 4                          Занятость: полная занятость   90 000 ₽ на руки
# ..                                                 ...                ...
# 395  Занятость: полная занятость, частичная занятос...   35 000 ₽ на руки
# 396  Занятость: полная занятость, частичная занятос...  160 000 ₽ на руки
# 397                        Занятость: полная занятость   90 000 ₽ на руки
# 398                        Занятость: полная занятость  120 000 ₽ на руки
# 399                        Занятость: полная занятость   35 000 ₽ на руки
#
#                                 Последнее место работы
# 0    Январь 2000 — по настоящее время24 года 5 месяцев
# 1     Январь 2006 — по настоящее время18 лет 5 месяцев
# 2      Июль 2021 — по настоящее время2 года 11 месяцев
# 3          September 1998 — currently25 years 9 months
# 4    Сентябрь 2015 — по настоящее время8 лет 9 месяцев
# ..                                                 ...
# 395    Февраль 2016 — по настоящее время8 лет 4 месяца
# 396                   Март 2022 — Август 20226 месяцев
# 397                Сентябрь 2022 — Июнь 202310 месяцев
# 398   Октябрь 2018 — по настоящее время5 лет 8 месяцев
# 399                    Февраль 2021 — Январь 20221 год
#
# [400 rows x 10 columns]

# %%
employers_data_frame.to_csv('output.csv', sep='\t', encoding='utf-8')
